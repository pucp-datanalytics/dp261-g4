# %% [markdown]
# # Sprint 5 - Dashboard Ejecutivo
#
# Este notebook documenta el dashboard ejecutivo implementado en `dashboard/c_app.py`. El objetivo es presentar el modelo a stakeholders no tecnicos, conectando metricas con decisiones de negocio.

# %% [markdown]
# ## Objetivo del dashboard
#
# Comunicar que problema resuelve el modelo, que tan bien identifica visitantes con intencion de compra, que valor economico estimado genera y que acciones comerciales se recomiendan.

# %% [markdown]
# ## Secciones implementadas
#
# - Portada ejecutiva
# - KPIs principales
# - Resumen ejecutivo automatico
# - Desempeno del modelo
# - Valor de negocio
# - Simulador interactivo de visitante
# - Analisis de segmentos
# - Recomendaciones de negocio
# - Handoff Sprint 6

# %% [markdown]
# ## Widgets usados
#
# `st.sidebar`, `st.tabs`, `st.columns`, `st.metric`, `st.selectbox`, `st.slider`, `st.checkbox`, `st.button`, `st.expander`, `st.dataframe`, `st.plotly_chart`, `st.info`, `st.success`, `st.warning`, `st.markdown`, `st.progress`.

# %%
from pathlib import Path

files = [
    'docs/dataset_pucp.csv',
    'models/c_final_model.pkl',
    'models/c_metrics_summary.csv',
    'models/c_validation_test_comparison.csv',
    'models/c_threshold_analysis.csv',
    'models/c_dashboard_kpis.csv',
    'models/c_dashboard_segments.csv',
    'models/c_dashboard_feature_summary.csv',
]

for file in files:
    print(file, Path(file).exists())

# %%
import pandas as pd

kpis = pd.read_csv('models/c_dashboard_kpis.csv')
kpis.T

# %% [markdown]
# ## Comando de ejecucion
#
# ```bash
# streamlit run dashboard/c_app.py
# ```

# %% [markdown]
# ## Aclaracion de alcance
#
# Este dashboard corresponde al Sprint 5. No implementa Sprint 6, no crea API, no crea Dockerfile y no despliega en AWS.
