# %% [markdown]
# # Sprint 2 - Pipeline
#
# Muestra split antes de fit, ColumnTransformer, imblearn Pipeline y persistencia.

# %% [markdown]
# Este notebook es un entregable academico. La logica principal vive en scripts reproducibles `src/c_*.py` y aqui se documenta/ejecuta el flujo con rutas relativas.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

import joblib
from sklearn.linear_model import LogisticRegression
from c_preprocessing import prepare_data, build_model_pipeline
X_train, X_test, y_train, y_test = prepare_data()
pipe = build_model_pipeline(LogisticRegression(max_iter=1000), use_smote=True)
pipe.fit(X_train, y_train)
print(pipe)
print(joblib.load('models/c_preproc.pkl'))

# %% [markdown]
# Notas: no se implementa Sprint 6, no se usan rutas absolutas, no se incluyen credenciales y el test set solo se usa para evaluacion final cuando corresponde.
