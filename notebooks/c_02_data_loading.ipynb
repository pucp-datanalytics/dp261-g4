# %% [markdown]
# # Sprint 1 - Data Loading
#
# Carga dataset desde docs, muestra shape, columnas, tipos y confirma target Revenue.

# %% [markdown]
# Este notebook es un entregable academico. La logica principal vive en scripts reproducibles `src/c_*.py` y aqui se documenta/ejecuta el flujo con rutas relativas.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

from c_preprocessing import copy_raw_dataset, load_raw_data, RAW_COPY, TARGET_COL
copy_raw_dataset()
df = load_raw_data()
print('copy:', RAW_COPY)
print(df.shape)
print(list(df.columns))
print(df.dtypes)
print('target ok:', TARGET_COL in df.columns)

# %% [markdown]
# Notas: no se implementa Sprint 6, no se usan rutas absolutas, no se incluyen credenciales y el test set solo se usa para evaluacion final cuando corresponde.
