# %% [markdown]
# # Sprint 1 - Prototype
#
# Prototipo simple para explorar variables y relaciones con Revenue.

# %% [markdown]
# Este notebook es un entregable academico. La logica principal vive en scripts reproducibles `src/c_*.py` y aqui se documenta/ejecuta el flujo con rutas relativas.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

import matplotlib.pyplot as plt
from c_preprocessing import load_raw_data
df = load_raw_data()
variable = 'PageValues'
df.boxplot(column=variable, by='Revenue', figsize=(7,4))
plt.suptitle('')
plt.show()

# %% [markdown]
# Notas: no se implementa Sprint 6, no se usan rutas absolutas, no se incluyen credenciales y el test set solo se usa para evaluacion final cuando corresponde.
