# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\Admin\proyecto\dp261-g4
# ['.dvc', '.dvcignore', '.git', '.gitignore', '.ipynb_checkpoints', '04_prototype.ipynb', 'data', 'environment.yml', 'notebooks', 'README.md']

# %%
print(os.listdir("data"))
# Out:
# ['processed', 'raw']

# %%
print(os.listdir("notebooks"))
# Out:
# ['.ipynb_checkpoints', '01_business.ipynb', '02_data_loading.ipynb', '03_eda.ipynb', '04_prototype.ipynb', 'Untitled.ipynb']

# %%
# %pip install matplotlib seaborn ipywidgets pandas
# Out:
# ...
#   Using cached matplotlib-3.10.8-cp313-cp313-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.62.1-cp313-cp313-win_amd64.whl.metadata (119 kB)
# ...
#   Using cached kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# ...
#   Using cached pillow-12.2.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 3.7 MB/s eta 0:00:02
# ...

# %%
print("RAW:", os.listdir("data/raw"))
print("PROCESSED:", os.listdir("data/processed"))
# Out:
# RAW: ['.gitkeep', 'dataset_pucp.csv.dvc']
# PROCESSED: ['.gitkeep']

# %%
df = pd.read_csv("data/processed/NOMBRE_DEL_ARCHIVO.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv("data/processed/NOMBRE_DEL_ARCHIVO.csv")
#       2 df.head()
#
# NameError: name 'pd' is not defined
